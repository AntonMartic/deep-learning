# %% [markdown]
# # TNM112 -- Lab 1
# Instructions about the different tasks are specified in this notebook. However, for more details, please see the PDF with lab instructions. Also see the lab report template for information on how to report your results.

# %% [markdown]
# ### Data generation
# Look through the "data_generator.py" code to understand how the dataset is generated and plotted.
#
# The "importlib" library is used to enable reloading of a library each time the cell is executed (so that changes to the imported script will be visible without restarting the notebook).

# %%
import importlib
import data_generator
importlib.reload(data_generator)

data = data_generator.DataGenerator()
data.generate(dataset='polar', N_train=512, N_test=512, K=2, sigma=0.1)
data.plot()
# Out:
# Data specification:
# 	Dataset type:           linear
# 	Number of classes:      2
# 	Std of classes:         0.1
# 	Training data shape:    (1024, 2)
# 	Validation data shape:  (1024, 2)
# 	Test data shape:        (1024, 2)

# %% [markdown]
# ### Keras MLP
# Look through the "keras_mlp.py" code to understand how the model is setup and trained.
#
# #### Task 1.1
# Use a linear dataset with N_train = 512 and K = 2. Specify a network without hidden layers. Compare:
# * Training for 4 epochs with learning rate 1.0 and batch size 512
# * Training for 4 epochs with learning rate 1.0 and batch size 16
#
# Answer the following questions:
# * Which model is best at separating the two classes (provide the accuracy on the test set)? Why is this the case? (Hint: how many iterations of SGD are performed in the two cases?)
# * Why is it possible to do the classification without non-linear activation function (there's only a softmax activation)?
#
# #### Task 1.2
# Use a polar dataset with N_train = 512 and K = 2. Specify a network with one hidden layer with 5 neurons. Train for 20 epochs with learning rate 1.0 and batch size 16. Compare:
# * Using linear activation function
# * Using sigmoid activation function
# * Using relu activation function
#
# Answer the following questions:
# * Why does linear activation not work?
# * On average, what is the best classification accuracy that can be achieved with a linear activation function?
# * Can you find an explanation for the difference comparing sigmoid and relu activation?
#
# #### Task 1.3
# Use a polar dataset with N_train = 512, K = 5, and sigma=0.05. Specify a network with 10 hidden layers with 50 neurons each and relu activation. Try different combinations of hyper parameters to get the best classification accuracy. Examples could be:
# * Change mean and stddev of normal initialization.
# * Change learning rate and add some momentum in SGD.
# * Check the Keras documentation for 'ExponentialDecay', which can be used to specify decaying learning rate for SGD.
# * You can also tweak batch size and number of epochs.
#
# What combination worked best, and what was your best classification accuracy (on the test set)? Can you find any patterns in what combinations of hyper parameters work and doesn't work?
#
# #### Task 1.4
# Continue from previous task, but change initialization to 'glorot_normal' and optimizer to 'keras.optimizers.Adam()'. Does this perform better compared to your results in Task 1.3?

# %%
import keras_mlp
importlib.reload(keras_mlp) 

from tensorflow import keras

# Uncomment to be able to change data specification (instead of having to run the above cell every time)
data.generate(dataset='linear', N_train=512, N_test=512, K=2, sigma=0.1) # Task 1.1
#data.generate(dataset='polar', N_train=512, N_test=512, K=2, sigma=0.1)  # Task 1.2
#data.generate(dataset='polar', N_train=512, N_test=512, K=5, sigma=0.05) # Task 1.3

# Hyper-parameters
hidden_layers = 10     # The number of hidden layers in the network (total number of layers will be L=hidden_layers+1)
layer_width = 50       # The number of neurons in each hidden layer
activation = 'relu' # Activation function of hidden layers
#init = keras.initializers.RandomNormal(mean=0.01, stddev=0.1) # Initialization method (starting point for the optimization)
init = keras.initializers.glorot_normal()
epochs = 100            # Number of epochs for the training
batch_size = 16      # Batch size to use in training
loss = keras.losses.MeanSquaredError() # Loss function

#opt = keras.optimizers.SGD(learning_rate=0.06, momentum=0.8) # Optimizer

""" # Exponential decay
initial_learning_rate = 0.1
lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate, decay_steps=500, decay_rate=0.9, staircase=True)
opt = keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.8)
"""

opt = keras.optimizers.Adam(learning_rate=0.0001)

# The Keras MLP model
model_k = keras_mlp.KerasMLP(data, verbose=True)

# Setup the model with the specified hyper parameters
model_k.setup_model(hidden_layers=hidden_layers, layer_width=layer_width,
                    activation=activation, init=init)

# Compile the model with a loss function and optimizer
model_k.compile(loss_fn=loss, optimizer=opt)

# Train the model a certain number of epochs with a specified batch size
model_k.train(epochs=epochs, batch_size=batch_size)

# Plot the training progress
model_k.plot_training()

# Evaluate the model (loss and accuracy on the training and test data)
model_k.evaluate()

# Plot the dataset with decision boundaries generated by the trained model
data.plot_classifier(model_k)
# Out:
# Data specification:
# 	Dataset type:           linear
# 	Number of classes:      2
# 	Std of classes:         0.1
# 	Training data shape:    (1024, 2)
# 	Validation data shape:  (1024, 2)
# 	Test data shape:        (1024, 2)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 50)             │           150 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 2)              │           102 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,202 (90.63 KB)
#  Trainable params: 23,202 (90.63 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4932 - loss: 0.2440 - val_accuracy: 0.5000 - val_loss: 0.2322
# Epoch 2/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5322 - loss: 0.2111 - val_accuracy: 0.6494 - val_loss: 0.1821
# Epoch 3/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8506 - loss: 0.1475 - val_accuracy: 0.9590 - val_loss: 0.1106
# Epoch 4/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9805 - loss: 0.0748 - val_accuracy: 0.9766 - val_loss: 0.0420
# Epoch 5/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9873 - loss: 0.0245 - val_accuracy: 0.9805 - val_loss: 0.0211
# Epoch 6/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9854 - loss: 0.0158 - val_accuracy: 0.9736 - val_loss: 0.0229
# Epoch 7/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9873 - loss: 0.0126 - val_accuracy: 0.9873 - val_loss: 0.0111
# Epoch 8/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9824 - loss: 0.0152 - val_accuracy: 0.9854 - val_loss: 0.0110
# Epoch 9/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9854 - loss: 0.0111 - val_accuracy: 0.9873 - val_loss: 0.0110
# Epoch 10/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9844 - loss: 0.0113 - val_accuracy: 0.9873 - val_loss: 0.0107
# Epoch 11/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0107 - val_accuracy: 0.9893 - val_loss: 0.0097
# Epoch 12/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9854 - loss: 0.0100 - val_accuracy: 0.9863 - val_loss: 0.0091
# Epoch 13/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9873 - loss: 0.0100 - val_accuracy: 0.9883 - val_loss: 0.0092
# Epoch 14/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9883 - loss: 0.0104 - val_accuracy: 0.9883 - val_loss: 0.0089
# Epoch 15/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0089 - val_accuracy: 0.9863 - val_loss: 0.0093
# Epoch 16/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0086 - val_accuracy: 0.9883 - val_loss: 0.0090
# Epoch 17/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9873 - loss: 0.0089 - val_accuracy: 0.9883 - val_loss: 0.0092
# Epoch 18/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0091 - val_accuracy: 0.9863 - val_loss: 0.0089
# Epoch 19/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9863 - loss: 0.0107 - val_accuracy: 0.9873 - val_loss: 0.0091
# Epoch 20/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9863 - loss: 0.0102 - val_accuracy: 0.9873 - val_loss: 0.0107
# Epoch 21/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0103 - val_accuracy: 0.9873 - val_loss: 0.0087
# Epoch 22/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0089 - val_accuracy: 0.9863 - val_loss: 0.0087
# Epoch 23/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9854 - loss: 0.0093 - val_accuracy: 0.9863 - val_loss: 0.0087
# Epoch 24/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0091 - val_accuracy: 0.9863 - val_loss: 0.0091
# Epoch 25/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9854 - loss: 0.0107 - val_accuracy: 0.9883 - val_loss: 0.0085
# Epoch 26/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0101 - val_accuracy: 0.9883 - val_loss: 0.0086
# Epoch 27/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.0092 - val_accuracy: 0.9854 - val_loss: 0.0110
# Epoch 28/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0083 - val_accuracy: 0.9873 - val_loss: 0.0086
# Epoch 29/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9873 - loss: 0.0088 - val_accuracy: 0.9863 - val_loss: 0.0088
# Epoch 30/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9873 - loss: 0.0091 - val_accuracy: 0.9863 - val_loss: 0.0087
# Epoch 31/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9863 - loss: 0.0101 - val_accuracy: 0.9795 - val_loss: 0.0158
# Epoch 32/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9873 - loss: 0.0101 - val_accuracy: 0.9863 - val_loss: 0.0086
# Epoch 33/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0085 - val_accuracy: 0.9873 - val_loss: 0.0092
# Epoch 34/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0082 - val_accuracy: 0.9893 - val_loss: 0.0094
# Epoch 35/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9824 - loss: 0.0120 - val_accuracy: 0.9814 - val_loss: 0.0147
# Epoch 36/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9863 - loss: 0.0099 - val_accuracy: 0.9863 - val_loss: 0.0089
# Epoch 37/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9854 - loss: 0.0091 - val_accuracy: 0.9883 - val_loss: 0.0110
# Epoch 38/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0095 - val_accuracy: 0.9863 - val_loss: 0.0090
# Epoch 39/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0088 - val_accuracy: 0.9873 - val_loss: 0.0089
# Epoch 40/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0081 - val_accuracy: 0.9863 - val_loss: 0.0088
# Epoch 41/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0089 - val_accuracy: 0.9873 - val_loss: 0.0086
# Epoch 42/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9873 - loss: 0.0091 - val_accuracy: 0.9883 - val_loss: 0.0098
# Epoch 43/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0085 - val_accuracy: 0.9883 - val_loss: 0.0114
# Epoch 44/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0084 - val_accuracy: 0.9854 - val_loss: 0.0106
# Epoch 45/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9854 - loss: 0.0102 - val_accuracy: 0.9883 - val_loss: 0.0090
# Epoch 46/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0090 - val_accuracy: 0.9883 - val_loss: 0.0093
# Epoch 47/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0084 - val_accuracy: 0.9873 - val_loss: 0.0103
# Epoch 48/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0084 - val_accuracy: 0.9854 - val_loss: 0.0116
# Epoch 49/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9863 - loss: 0.0106 - val_accuracy: 0.9883 - val_loss: 0.0087
# Epoch 50/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0095 - val_accuracy: 0.9854 - val_loss: 0.0106
# Epoch 51/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0089 - val_accuracy: 0.9873 - val_loss: 0.0086
# Epoch 52/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0091 - val_accuracy: 0.9873 - val_loss: 0.0087
# Epoch 53/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0082 - val_accuracy: 0.9873 - val_loss: 0.0094
# Epoch 54/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0091 - val_accuracy: 0.9883 - val_loss: 0.0092
# Epoch 55/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0079 - val_accuracy: 0.9873 - val_loss: 0.0086
# Epoch 56/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9863 - loss: 0.0097 - val_accuracy: 0.9863 - val_loss: 0.0101
# Epoch 57/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0087 - val_accuracy: 0.9883 - val_loss: 0.0089
# Epoch 58/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0088 - val_accuracy: 0.9883 - val_loss: 0.0093
# Epoch 59/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9854 - loss: 0.0089 - val_accuracy: 0.9883 - val_loss: 0.0092
# Epoch 60/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0086 - val_accuracy: 0.9873 - val_loss: 0.0090
# Epoch 61/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0086 - val_accuracy: 0.9883 - val_loss: 0.0103
# Epoch 62/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0084 - val_accuracy: 0.9893 - val_loss: 0.0095
# Epoch 63/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0073 - val_accuracy: 0.9873 - val_loss: 0.0097
# Epoch 64/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0090 - val_accuracy: 0.9883 - val_loss: 0.0093
# Epoch 65/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0086 - val_accuracy: 0.9883 - val_loss: 0.0093
# Epoch 66/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9873 - loss: 0.0101 - val_accuracy: 0.9863 - val_loss: 0.0088
# Epoch 67/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.0083 - val_accuracy: 0.9873 - val_loss: 0.0088
# Epoch 68/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0084 - val_accuracy: 0.9883 - val_loss: 0.0092
# Epoch 69/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9873 - loss: 0.0100 - val_accuracy: 0.9834 - val_loss: 0.0129
# Epoch 70/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9922 - loss: 0.0078 - val_accuracy: 0.9873 - val_loss: 0.0088
# Epoch 71/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0081 - val_accuracy: 0.9854 - val_loss: 0.0116
# Epoch 72/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0077 - val_accuracy: 0.9883 - val_loss: 0.0100
# Epoch 73/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0076 - val_accuracy: 0.9854 - val_loss: 0.0117
# Epoch 74/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0089 - val_accuracy: 0.9863 - val_loss: 0.0088
# Epoch 75/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0081 - val_accuracy: 0.9824 - val_loss: 0.0134
# Epoch 76/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0082 - val_accuracy: 0.9863 - val_loss: 0.0091
# Epoch 77/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9873 - loss: 0.0092 - val_accuracy: 0.9863 - val_loss: 0.0088
# Epoch 78/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0090 - val_accuracy: 0.9873 - val_loss: 0.0089
# Epoch 79/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0080 - val_accuracy: 0.9863 - val_loss: 0.0102
# Epoch 80/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0087 - val_accuracy: 0.9854 - val_loss: 0.0120
# Epoch 81/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9863 - loss: 0.0096 - val_accuracy: 0.9883 - val_loss: 0.0088
# Epoch 82/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0080 - val_accuracy: 0.9834 - val_loss: 0.0129
# Epoch 83/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0091 - val_accuracy: 0.9883 - val_loss: 0.0098
# Epoch 84/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0082 - val_accuracy: 0.9883 - val_loss: 0.0088
# Epoch 85/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0081 - val_accuracy: 0.9883 - val_loss: 0.0090
# Epoch 86/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0087 - val_accuracy: 0.9873 - val_loss: 0.0105
# Epoch 87/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0090 - val_accuracy: 0.9883 - val_loss: 0.0085
# Epoch 88/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0086 - val_accuracy: 0.9873 - val_loss: 0.0093
# Epoch 89/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0081 - val_accuracy: 0.9863 - val_loss: 0.0091
# Epoch 90/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0079 - val_accuracy: 0.9883 - val_loss: 0.0089
# Epoch 91/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0082 - val_accuracy: 0.9863 - val_loss: 0.0090
# Epoch 92/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0084 - val_accuracy: 0.9873 - val_loss: 0.0089
# Epoch 93/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0088 - val_accuracy: 0.9893 - val_loss: 0.0094
# Epoch 94/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0077 - val_accuracy: 0.9863 - val_loss: 0.0106
# Epoch 95/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9893 - loss: 0.0102 - val_accuracy: 0.9795 - val_loss: 0.0146
# Epoch 96/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0087 - val_accuracy: 0.9863 - val_loss: 0.0104
# Epoch 97/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0091 - val_accuracy: 0.9873 - val_loss: 0.0088
# Epoch 98/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0090 - val_accuracy: 0.9883 - val_loss: 0.0093
# Epoch 99/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0078 - val_accuracy: 0.9863 - val_loss: 0.0114
# Epoch 100/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9883 - loss: 0.0091 - val_accuracy: 0.9883 - val_loss: 0.0090
# Model performance:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - accuracy: 0.9902 - loss: 0.0076
# 	Train loss:     0.0076
# 	Train accuracy: 99.02
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - accuracy: 0.9844 - loss: 0.0102
# 	Test loss:      0.0102
# 	Test accuracy:  98.44
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 0s 307us/step
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# ### Our MLP
# To make sure our implementation of the MLP works as intended, we can run inference using the weights we trained with Keras. Then we can see if we get the same results in terms of accuracy and the decision boundaries generated by the model.
#
# #### Task 2
# Implement the "activation", "setup_model", "feedforward", and "evaluate" functions in "mlp.py". Run this cell and compare the results to the results generated by the Keras model in the previous cell (compare number of weights, classification loss/accuracy, and the plots with decision boundaries). Test this for different specifications of the model in the previous cell (number of hidden layers, layer width, and activation function)
#
# #### Task 3
# Use the linear dataset with 2 classes (K=2). Change the specification of the model parameters. Instead of extracting the weights from the Keras model, you should manually specify a weight matrix (2x2) and a bias vector (2x1), i.e. no hidden layers. Remember that each layer is supposed to be an item in a list, which means that you need to specify the weight matrix and the bias vector in separate 1-item lists. As we only have one layer, it will use the 'softmax' activation function.
# * Manually derive weights and biases to specify a model that draws a decision boundary at x2 = 1-x1. What is the simplest possible solution? How many additional solutions are possible?
# * How can you, in the simplest way, change the weights/biases to switch the predicted class labels?
# * By writing out the output of the MLP, motivate why your choice of weights and biases creates a decision boundary at x2 = 1-x1. Can you find a general formula for specifying which combinations of weights and biases will generate the decision boundary?

# %%
import numpy as np
import mlp
importlib.reload(mlp)

# Get the weight matrices and biases of the trained Keras model
W, b = model_k.get_weights()

# Task 3: specify a weight matrix and a bias vector
# W = [np.array([[1, 1],[0, 0]])]
# b = [np.array([[-1], [0]])]

# change the weights/biases to switch the predicted class labels
W = [np.array([[0, 0],[1, 1]])]
b = [np.array([[0], [-1]])]

# This is our implementation of an MLP, which we set to use the dataset we generated
model = mlp.MLP(data)

# Assign the weights and biases to the MLP and specify the activation function
model.setup_model(W, b, activation=activation)

# Evaluate the model (accuracy on the training and test data)
model.evaluate()

# Plot the dataset with decision boundaries generated by our MLP
data.plot_classifier(model)
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Number of hidden layers:  0
# Number of model weights:  6
# Model performance:
# 	Train loss:     0.1759
# 	Train accuracy: 0.99
# 	Test loss:      0.1764
# 	Test accuracy:  0.99
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
