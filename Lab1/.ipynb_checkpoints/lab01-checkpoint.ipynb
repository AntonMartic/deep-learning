# %% [markdown]
# # TNM112 -- Lab 1
# Instructions about the different tasks are specified in this notebook. However, for more details, please see the PDF with lab instructions. Also see the lab report template for information on how to report your results.

# %% [markdown]
# ### Data generation
# Look through the "data_generator.py" code to understand how the dataset is generated and plotted.
#
# The "importlib" library is used to enable reloading of a library each time the cell is executed (so that changes to the imported script will be visible without restarting the notebook).

# %%
import importlib
import data_generator
importlib.reload(data_generator)

data = data_generator.DataGenerator()
data.generate(dataset='polar', N_train=512, N_test=512, K=2, sigma=0.1)
data.plot()
# Out:
# Data specification:
# 	Dataset type:           polar
# 	Number of classes:      2
# 	Std of classes:         0.1
# 	Training data shape:    (1024, 2)
# 	Validation data shape:  (1024, 2)
# 	Test data shape:        (1024, 2)

# %% [markdown]
# ### Keras MLP
# Look through the "keras_mlp.py" code to understand how the model is setup and trained.
#
# #### Task 1.1
# Use a linear dataset with N_train = 512 and K = 2. Specify a network without hidden layers. Compare:
# * Training for 4 epochs with learning rate 1.0 and batch size 512
# * Training for 4 epochs with learning rate 1.0 and batch size 16
#
# Answer the following questions:
# * Which model is best at separating the two classes (provide the accuracy on the test set)? Why is this the case? (Hint: how many iterations of SGD are performed in the two cases?)
# * Why is it possible to do the classification without non-linear activation function (there's only a softmax activation)?
#
# #### Task 1.2
# Use a polar dataset with N_train = 512 and K = 2. Specify a network with one hidden layer with 5 neurons. Train for 20 epochs with learning rate 1.0 and batch size 16. Compare:
# * Using linear activation function
# * Using sigmoid activation function
# * Using relu activation function
#
# Answer the following questions:
# * Why does linear activation not work?
# * On average, what is the best classification accuracy that can be achieved with a linear activation function?
# * Can you find an explanation for the difference comparing sigmoid and relu activation?
#
# #### Task 1.3
# Use a polar dataset with N_train = 512, K = 5, and sigma=0.05. Specify a network with 10 hidden layers with 50 neurons each and relu activation. Try different combinations of hyper parameters to get the best classification accuracy. Examples could be:
# * Change mean and stddev of normal initialization.
# * Change learning rate and add some momentum in SGD.
# * Check the Keras documentation for 'ExponentialDecay', which can be used to specify decaying learning rate for SGD.
# * You can also tweak batch size and number of epochs.
#
# What combination worked best, and what was your best classification accuracy (on the test set)? Can you find any patterns in what combinations of hyper parameters work and doesn't work?
#
# #### Task 1.4
# Continue from previous task, but change initialization to 'glorot_normal' and optimizer to 'keras.optimizers.Adam()'. Does this perform better compared to your results in Task 1.3?

# %%
import keras_mlp
importlib.reload(keras_mlp) 

from tensorflow import keras

# Uncomment to be able to change data specification (instead of having to run the above cell every time)
#data.generate(dataset='linear', N_train=512, N_test=512, K=2, sigma=0.1) # Task 1.1
#data.generate(dataset='polar', N_train=512, N_test=512, K=2, sigma=0.1)  # Task 1.2
data.generate(dataset='polar', N_train=512, N_test=512, K=5, sigma=0.05) # Task 1.3

# Hyper-parameters
hidden_layers = 10     # The number of hidden layers in the network (total number of layers will be L=hidden_layers+1)
layer_width = 50       # The number of neurons in each hidden layer
activation = 'relu' # Activation function of hidden layers
init = keras.initializers.RandomNormal(mean=0.01, stddev=0.1) # Initialization method (starting point for the optimization)
epochs = 100            # Number of epochs for the training
batch_size = 16      # Batch size to use in training
loss = keras.losses.MeanSquaredError() # Loss function

# Exponential decay
initial_learning_rate = 0.1
lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate, decay_steps=500, decay_rate=0.9, staircase=True)
opt = keras.optimizers.SGD(learning_rate=lr_schedule, momentum=0.8)

#opt = keras.optimizers.SGD(learning_rate=0.06, momentum=0.8) # Optimizer

# The Keras MLP model
model_k = keras_mlp.KerasMLP(data, verbose=True)

# Setup the model with the specified hyper parameters
model_k.setup_model(hidden_layers=hidden_layers, layer_width=layer_width,
                    activation=activation, init=init)

# Compile the model with a loss function and optimizer
model_k.compile(loss_fn=loss, optimizer=opt)

# Train the model a certain number of epochs with a specified batch size
model_k.train(epochs=epochs, batch_size=batch_size)

# Plot the training progress
model_k.plot_training()

# Evaluate the model (loss and accuracy on the training and test data)
model_k.evaluate()

# Plot the dataset with decision boundaries generated by the trained model
data.plot_classifier(model_k)
# Out:
# Data specification:
# 	Dataset type:           polar
# 	Number of classes:      5
# 	Std of classes:         0.05
# 	Training data shape:    (2560, 2)
# 	Validation data shape:  (2560, 2)
# 	Test data shape:        (2560, 2)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 50)             │           150 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 5)              │           255 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,355 (91.23 KB)
#  Trainable params: 23,355 (91.23 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2051 - loss: 0.1600 - val_accuracy: 0.2000 - val_loss: 0.1599
# Epoch 2/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.2023 - loss: 0.1600 - val_accuracy: 0.2000 - val_loss: 0.1599
# Epoch 3/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 0.1945 - loss: 0.1599 - val_accuracy: 0.2000 - val_loss: 0.1598
# Epoch 4/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - accuracy: 0.2367 - loss: 0.1598 - val_accuracy: 0.2000 - val_loss: 0.1597
# Epoch 5/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 0.2664 - loss: 0.1597 - val_accuracy: 0.3629 - val_loss: 0.1595
# Epoch 6/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3160 - loss: 0.1593 - val_accuracy: 0.3562 - val_loss: 0.1589
# Epoch 7/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.3613 - loss: 0.1578 - val_accuracy: 0.3996 - val_loss: 0.1561
# Epoch 8/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.4020 - loss: 0.1408 - val_accuracy: 0.4574 - val_loss: 0.1167
# Epoch 9/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.6590 - loss: 0.0958 - val_accuracy: 0.8992 - val_loss: 0.0562
# Epoch 10/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.7012 - loss: 0.0947 - val_accuracy: 0.7563 - val_loss: 0.0610
# Epoch 11/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - accuracy: 0.7133 - loss: 0.0900 - val_accuracy: 0.8090 - val_loss: 0.0473
# Epoch 12/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - accuracy: 0.7953 - loss: 0.0617 - val_accuracy: 0.7406 - val_loss: 0.0706
# Epoch 13/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.8176 - loss: 0.0534 - val_accuracy: 0.8973 - val_loss: 0.0323
# Epoch 14/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - accuracy: 0.8316 - loss: 0.0500 - val_accuracy: 0.9070 - val_loss: 0.0334
# Epoch 15/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.8484 - loss: 0.0467 - val_accuracy: 0.8359 - val_loss: 0.0492
# Epoch 16/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.8246 - loss: 0.0555 - val_accuracy: 0.7504 - val_loss: 0.0959
# Epoch 17/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.7758 - loss: 0.0784 - val_accuracy: 0.6430 - val_loss: 0.1274
# Epoch 18/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 0.8488 - loss: 0.0499 - val_accuracy: 0.9383 - val_loss: 0.0185
# Epoch 19/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.8492 - loss: 0.0458 - val_accuracy: 0.9410 - val_loss: 0.0203
# Epoch 20/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.9047 - loss: 0.0286 - val_accuracy: 0.9305 - val_loss: 0.0233
# Epoch 21/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.8863 - loss: 0.0352 - val_accuracy: 0.9273 - val_loss: 0.0217
# Epoch 22/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.8895 - loss: 0.0340 - val_accuracy: 0.9367 - val_loss: 0.0212
# Epoch 23/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9211 - loss: 0.0255 - val_accuracy: 0.9266 - val_loss: 0.0227
# Epoch 24/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.8859 - loss: 0.0337 - val_accuracy: 0.9223 - val_loss: 0.0243
# Epoch 25/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 0.8992 - loss: 0.0305 - val_accuracy: 0.9105 - val_loss: 0.0271
# Epoch 26/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.9180 - loss: 0.0260 - val_accuracy: 0.9020 - val_loss: 0.0296
# Epoch 27/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.9109 - loss: 0.0285 - val_accuracy: 0.9527 - val_loss: 0.0149
# Epoch 28/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.9301 - loss: 0.0222 - val_accuracy: 0.9234 - val_loss: 0.0241
# Epoch 29/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.9305 - loss: 0.0218 - val_accuracy: 0.9371 - val_loss: 0.0195
# Epoch 30/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - accuracy: 0.9125 - loss: 0.0264 - val_accuracy: 0.9332 - val_loss: 0.0210
# Epoch 31/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.9336 - loss: 0.0204 - val_accuracy: 0.9422 - val_loss: 0.0181
# Epoch 32/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - accuracy: 0.9375 - loss: 0.0195 - val_accuracy: 0.9531 - val_loss: 0.0148
# Epoch 33/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.9273 - loss: 0.0223 - val_accuracy: 0.9414 - val_loss: 0.0186
# Epoch 34/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.9348 - loss: 0.0213 - val_accuracy: 0.8953 - val_loss: 0.0306
# Epoch 35/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.9187 - loss: 0.0244 - val_accuracy: 0.9574 - val_loss: 0.0133
# Epoch 36/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - accuracy: 0.9340 - loss: 0.0207 - val_accuracy: 0.9336 - val_loss: 0.0190
# Epoch 37/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9359 - loss: 0.0202 - val_accuracy: 0.9469 - val_loss: 0.0164
# Epoch 38/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.9379 - loss: 0.0196 - val_accuracy: 0.9602 - val_loss: 0.0135
# Epoch 39/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - accuracy: 0.9430 - loss: 0.0176 - val_accuracy: 0.9508 - val_loss: 0.0157
# Epoch 40/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.9410 - loss: 0.0180 - val_accuracy: 0.9516 - val_loss: 0.0143
# Epoch 41/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.9375 - loss: 0.0198 - val_accuracy: 0.9000 - val_loss: 0.0305
# Epoch 42/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.9363 - loss: 0.0200 - val_accuracy: 0.9461 - val_loss: 0.0161
# Epoch 43/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.9320 - loss: 0.0209 - val_accuracy: 0.9500 - val_loss: 0.0151
# Epoch 44/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.9414 - loss: 0.0175 - val_accuracy: 0.9578 - val_loss: 0.0135
# Epoch 45/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - accuracy: 0.9414 - loss: 0.0176 - val_accuracy: 0.9438 - val_loss: 0.0173
# Epoch 46/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.9246 - loss: 0.0231 - val_accuracy: 0.9410 - val_loss: 0.0189
# Epoch 47/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.9406 - loss: 0.0178 - val_accuracy: 0.9246 - val_loss: 0.0230
# Epoch 48/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - accuracy: 0.9523 - loss: 0.0154 - val_accuracy: 0.9430 - val_loss: 0.0172
# Epoch 49/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.9488 - loss: 0.0167 - val_accuracy: 0.9422 - val_loss: 0.0174
# Epoch 50/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.9434 - loss: 0.0175 - val_accuracy: 0.9301 - val_loss: 0.0208
# Epoch 51/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.9449 - loss: 0.0167 - val_accuracy: 0.9547 - val_loss: 0.0140
# Epoch 52/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - accuracy: 0.9516 - loss: 0.0148 - val_accuracy: 0.9551 - val_loss: 0.0138
# Epoch 53/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.9566 - loss: 0.0139 - val_accuracy: 0.9523 - val_loss: 0.0155
# Epoch 54/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9508 - loss: 0.0152 - val_accuracy: 0.9566 - val_loss: 0.0133
# Epoch 55/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.9535 - loss: 0.0139 - val_accuracy: 0.9504 - val_loss: 0.0149
# Epoch 56/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.9555 - loss: 0.0142 - val_accuracy: 0.9539 - val_loss: 0.0142
# Epoch 57/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.9539 - loss: 0.0142 - val_accuracy: 0.9535 - val_loss: 0.0140
# Epoch 58/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - accuracy: 0.9496 - loss: 0.0160 - val_accuracy: 0.9457 - val_loss: 0.0158
# Epoch 59/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.9590 - loss: 0.0140 - val_accuracy: 0.9406 - val_loss: 0.0181
# Epoch 60/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.9520 - loss: 0.0145 - val_accuracy: 0.9465 - val_loss: 0.0150
# Epoch 61/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.9555 - loss: 0.0136 - val_accuracy: 0.9348 - val_loss: 0.0193
# Epoch 62/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.9566 - loss: 0.0135 - val_accuracy: 0.9488 - val_loss: 0.0159
# Epoch 63/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9531 - loss: 0.0139 - val_accuracy: 0.9508 - val_loss: 0.0142
# Epoch 64/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.9559 - loss: 0.0142 - val_accuracy: 0.9500 - val_loss: 0.0148
# Epoch 65/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.9535 - loss: 0.0135 - val_accuracy: 0.9512 - val_loss: 0.0146
# Epoch 66/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.9574 - loss: 0.0132 - val_accuracy: 0.9512 - val_loss: 0.0152
# Epoch 67/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.9582 - loss: 0.0131 - val_accuracy: 0.9598 - val_loss: 0.0127
# Epoch 68/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.9543 - loss: 0.0134 - val_accuracy: 0.9488 - val_loss: 0.0148
# Epoch 69/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.9543 - loss: 0.0138 - val_accuracy: 0.9527 - val_loss: 0.0144
# Epoch 70/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.9586 - loss: 0.0124 - val_accuracy: 0.9492 - val_loss: 0.0154
# Epoch 71/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - accuracy: 0.9605 - loss: 0.0121 - val_accuracy: 0.9512 - val_loss: 0.0139
# Epoch 72/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.9598 - loss: 0.0124 - val_accuracy: 0.9520 - val_loss: 0.0151
# Epoch 73/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.9594 - loss: 0.0128 - val_accuracy: 0.9609 - val_loss: 0.0124
# Epoch 74/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.9590 - loss: 0.0128 - val_accuracy: 0.9551 - val_loss: 0.0146
# Epoch 75/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9590 - loss: 0.0129 - val_accuracy: 0.9547 - val_loss: 0.0135
# Epoch 76/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.9578 - loss: 0.0129 - val_accuracy: 0.9527 - val_loss: 0.0142
# Epoch 77/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.9598 - loss: 0.0121 - val_accuracy: 0.9555 - val_loss: 0.0135
# Epoch 78/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - accuracy: 0.9582 - loss: 0.0121 - val_accuracy: 0.9535 - val_loss: 0.0147
# Epoch 79/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.9617 - loss: 0.0120 - val_accuracy: 0.9586 - val_loss: 0.0131
# Epoch 80/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.9586 - loss: 0.0122 - val_accuracy: 0.9574 - val_loss: 0.0130
# Epoch 81/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - accuracy: 0.9559 - loss: 0.0130 - val_accuracy: 0.9594 - val_loss: 0.0131
# Epoch 82/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.9598 - loss: 0.0119 - val_accuracy: 0.9582 - val_loss: 0.0131
# Epoch 83/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - accuracy: 0.9625 - loss: 0.0120 - val_accuracy: 0.9348 - val_loss: 0.0196
# Epoch 84/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.9574 - loss: 0.0120 - val_accuracy: 0.9566 - val_loss: 0.0138
# Epoch 85/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.9617 - loss: 0.0118 - val_accuracy: 0.9566 - val_loss: 0.0138
# Epoch 86/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9594 - loss: 0.0122 - val_accuracy: 0.9566 - val_loss: 0.0133
# Epoch 87/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - accuracy: 0.9637 - loss: 0.0117 - val_accuracy: 0.9563 - val_loss: 0.0140
# Epoch 88/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.9605 - loss: 0.0118 - val_accuracy: 0.9520 - val_loss: 0.0143
# Epoch 89/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.9617 - loss: 0.0119 - val_accuracy: 0.9500 - val_loss: 0.0147
# Epoch 90/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 0.9617 - loss: 0.0116 - val_accuracy: 0.9574 - val_loss: 0.0135
# Epoch 91/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.9637 - loss: 0.0115 - val_accuracy: 0.9602 - val_loss: 0.0128
# Epoch 92/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.9621 - loss: 0.0118 - val_accuracy: 0.9594 - val_loss: 0.0130
# Epoch 93/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.9621 - loss: 0.0114 - val_accuracy: 0.9594 - val_loss: 0.0129
# Epoch 94/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - accuracy: 0.9645 - loss: 0.0113 - val_accuracy: 0.9559 - val_loss: 0.0133
# Epoch 95/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.9633 - loss: 0.0110 - val_accuracy: 0.9496 - val_loss: 0.0142
# Epoch 96/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9629 - loss: 0.0116 - val_accuracy: 0.9574 - val_loss: 0.0131
# Epoch 97/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - accuracy: 0.9605 - loss: 0.0116 - val_accuracy: 0.9563 - val_loss: 0.0134
# Epoch 98/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.9648 - loss: 0.0112 - val_accuracy: 0.9582 - val_loss: 0.0129
# Epoch 99/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - accuracy: 0.9648 - loss: 0.0114 - val_accuracy: 0.9547 - val_loss: 0.0137
# Epoch 100/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - accuracy: 0.9629 - loss: 0.0112 - val_accuracy: 0.9547 - val_loss: 0.0138
# Model performance:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - accuracy: 0.9664 - loss: 0.0104
# 	Train loss:     0.0104
# 	Train accuracy: 96.64
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - accuracy: 0.9598 - loss: 0.0130
# 	Test loss:      0.0130
# 	Test accuracy:  95.98
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 0s 258us/step
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# ### Our MLP
# To make sure our implementation of the MLP works as intended, we can run inference using the weights we trained with Keras. Then we can see if we get the same results in terms of accuracy and the decision boundaries generated by the model.
#
# #### Task 2
# Implement the "activation", "setup_model", "feedforward", and "evaluate" functions in "mlp.py". Run this cell and compare the results to the results generated by the Keras model in the previous cell (compare number of weights, classification loss/accuracy, and the plots with decision boundaries). Test this for different specifications of the model in the previous cell (number of hidden layers, layer width, and activation function)
#
# #### Task 3
# Use the linear dataset with 2 classes (K=2). Change the specification of the model parameters. Instead of extracting the weights from the Keras model, you should manually specify a weight matrix (2x2) and a bias vector (2x1), i.e. no hidden layers. Remember that each layer is supposed to be an item in a list, which means that you need to specify the weight matrix and the bias vector in separate 1-item lists. As we only have one layer, it will use the 'softmax' activation function.
# * Manually derive weights and biases to specify a model that draws a decision boundary at x2 = 1-x1. What is the simplest possible solution? How many additional solutions are possible?
# * How can you, in the simplest way, change the weights/biases to switch the predicted class labels?
# * By writing out the output of the MLP, motivate why your choice of weights and biases creates a decision boundary at x2 = 1-x1. Can you find a general formula for specifying which combinations of weights and biases will generate the decision boundary?

# %%
import numpy as np
import mlp
importlib.reload(mlp)

# Get the weight matrices and biases of the trained Keras model
W, b = model_k.get_weights()

# Task 3: specify a weight matrix and a bias vector
#W = TODO
#b = TODO

# This is our implementation of an MLP, which we set to use the dataset we generated
model = mlp.MLP(data)

# Assign the weights and biases to the MLP and specify the activation function
model.setup_model(W, b, activation=activation)

# Evaluate the model (accuracy on the training and test data)
model.evaluate()

# Plot the dataset with decision boundaries generated by our MLP
data.plot_classifier(model)
