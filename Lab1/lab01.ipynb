# %% [markdown]
# # TNM112 -- Lab 1
# Instructions about the different tasks are specified in this notebook. However, for more details, please see the PDF with lab instructions. Also see the lab report template for information on how to report your results.

# %% [markdown]
# ### Data generation
# Look through the "data_generator.py" code to understand how the dataset is generated and plotted.
#
# The "importlib" library is used to enable reloading of a library each time the cell is executed (so that changes to the imported script will be visible without restarting the notebook).

# %%
import importlib
import data_generator
importlib.reload(data_generator)

data = data_generator.DataGenerator()
data.generate(dataset='polar', N_train=512, N_test=512, K=2, sigma=0.1)
data.plot()
# Out:
# Data specification:
# 	Dataset type:           polar
# 	Number of classes:      2
# 	Std of classes:         0.1
# 	Training data shape:    (1024, 2)
# 	Validation data shape:  (1024, 2)
# 	Test data shape:        (1024, 2)

# %% [markdown]
# ### Keras MLP
# Look through the "keras_mlp.py" code to understand how the model is setup and trained.
#
# #### Task 1.1
# Use a linear dataset with N_train = 512 and K = 2. Specify a network without hidden layers. Compare:
# * Training for 4 epochs with learning rate 1.0 and batch size 512
# * Training for 4 epochs with learning rate 1.0 and batch size 16
#
# Answer the following questions:
# * Which model is best at separating the two classes (provide the accuracy on the test set)? Why is this the case? (Hint: how many iterations of SGD are performed in the two cases?)
# * Why is it possible to do the classification without non-linear activation function (there's only a softmax activation)?
#
# #### Task 1.2
# Use a polar dataset with N_train = 512 and K = 2. Specify a network with one hidden layer with 5 neurons. Train for 20 epochs with learning rate 1.0 and batch size 16. Compare:
# * Using linear activation function
# * Using sigmoid activation function
# * Using relu activation function
#
# Answer the following questions:
# * Why does linear activation not work?
# * On average, what is the best classification accuracy that can be achieved with a linear activation function?
# * Can you find an explanation for the difference comparing sigmoid and relu activation?
#
# #### Task 1.3
# Use a polar dataset with N_train = 512, K = 5, and sigma=0.05. Specify a network with 10 hidden layers with 50 neurons each and relu activation. Try different combinations of hyper parameters to get the best classification accuracy. Examples could be:
# * Change mean and stddev of normal initialization.
# * Change learning rate and add some momentum in SGD.
# * Check the Keras documentation for 'ExponentialDecay', which can be used to specify decaying learning rate for SGD.
# * You can also tweak batch size and number of epochs.
#
# What combination worked best, and what was your best classification accuracy (on the test set)? Can you find any patterns in what combinations of hyper parameters work and doesn't work?
#
# #### Task 1.4
# Continue from previous task, but change initialization to 'glorot_normal' and optimizer to 'keras.optimizers.Adam()'. Does this perform better compared to your results in Task 1.3?

# %%
import keras_mlp
importlib.reload(keras_mlp) 

from tensorflow import keras

# Uncomment to be able to change data specification (instead of having to run the above cell every time)
#data.generate(dataset='linear', N_train=512, N_test=512, K=2, sigma=0.1) # Task 1.1
#data.generate(dataset='polar', N_train=512, N_test=512, K=2, sigma=0.1)  # Task 1.2
data.generate(dataset='polar', N_train=512, N_test=512, K=5, sigma=0.05) # Task 1.3

# Hyper-parameters
hidden_layers = 10     # The number of hidden layers in the network (total number of layers will be L=hidden_layers+1)
layer_width = 50       # The number of neurons in each hidden layer
activation = 'relu' # Activation function of hidden layers
init = keras.initializers.RandomNormal(mean=0.01, stddev=0.1) # Initialization method (starting point for the optimization)
epochs = 100            # Number of epochs for the training
batch_size = 16      # Batch size to use in training
loss = keras.losses.MeanSquaredError() # Loss function
opt = keras.optimizers.SGD(learning_rate=0.06, momentum=0.8) # Optimizer

# The Keras MLP model
model_k = keras_mlp.KerasMLP(data, verbose=True)

# Setup the model with the specified hyper parameters
model_k.setup_model(hidden_layers=hidden_layers, layer_width=layer_width,
                    activation=activation, init=init)

# Compile the model with a loss function and optimizer
model_k.compile(loss_fn=loss, optimizer=opt)

# Train the model a certain number of epochs with a specified batch size
model_k.train(epochs=epochs, batch_size=batch_size)

# Plot the training progress
model_k.plot_training()

# Evaluate the model (loss and accuracy on the training and test data)
model_k.evaluate()

# Plot the dataset with decision boundaries generated by the trained model
data.plot_classifier(model_k)
# Out:
# Data specification:
# 	Dataset type:           polar
# 	Number of classes:      5
# 	Std of classes:         0.05
# 	Training data shape:    (2560, 2)
# 	Validation data shape:  (2560, 2)
# 	Test data shape:        (2560, 2)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 50)             │           150 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 50)             │         2,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 5)              │           255 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,355 (91.23 KB)
#  Trainable params: 23,355 (91.23 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1844 - loss: 0.1600 - val_accuracy: 0.2000 - val_loss: 0.1600
# Epoch 2/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - accuracy: 0.2000 - loss: 0.1600 - val_accuracy: 0.2000 - val_loss: 0.1600
# Epoch 3/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.1891 - loss: 0.1600 - val_accuracy: 0.2000 - val_loss: 0.1600
# Epoch 4/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.1973 - loss: 0.1600 - val_accuracy: 0.3383 - val_loss: 0.1599
# Epoch 5/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.2148 - loss: 0.1600 - val_accuracy: 0.2000 - val_loss: 0.1599
# Epoch 6/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.2012 - loss: 0.1600 - val_accuracy: 0.2000 - val_loss: 0.1599
# Epoch 7/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.2227 - loss: 0.1600 - val_accuracy: 0.2000 - val_loss: 0.1599
# Epoch 8/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.2148 - loss: 0.1600 - val_accuracy: 0.2000 - val_loss: 0.1599
# Epoch 9/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.2000 - loss: 0.1600 - val_accuracy: 0.2051 - val_loss: 0.1599
# Epoch 10/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.2227 - loss: 0.1599 - val_accuracy: 0.3223 - val_loss: 0.1599
# Epoch 11/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - accuracy: 0.2215 - loss: 0.1599 - val_accuracy: 0.3082 - val_loss: 0.1599
# Epoch 12/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 0.2441 - loss: 0.1599 - val_accuracy: 0.2438 - val_loss: 0.1598
# Epoch 13/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.2508 - loss: 0.1598 - val_accuracy: 0.2637 - val_loss: 0.1598
# Epoch 14/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.2203 - loss: 0.1598 - val_accuracy: 0.2000 - val_loss: 0.1597
# Epoch 15/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.2488 - loss: 0.1596 - val_accuracy: 0.2000 - val_loss: 0.1595
# Epoch 16/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 0.3105 - loss: 0.1595 - val_accuracy: 0.3992 - val_loss: 0.1592
# Epoch 17/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.3039 - loss: 0.1590 - val_accuracy: 0.4000 - val_loss: 0.1585
# Epoch 18/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - accuracy: 0.4141 - loss: 0.1574 - val_accuracy: 0.4000 - val_loss: 0.1553
# Epoch 19/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.4000 - loss: 0.1462 - val_accuracy: 0.4000 - val_loss: 0.1301
# Epoch 20/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.4461 - loss: 0.1202 - val_accuracy: 0.5582 - val_loss: 0.1096
# Epoch 21/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - accuracy: 0.6500 - loss: 0.0996 - val_accuracy: 0.7371 - val_loss: 0.0893
# Epoch 22/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.6902 - loss: 0.0874 - val_accuracy: 0.7832 - val_loss: 0.0716
# Epoch 23/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.7488 - loss: 0.0753 - val_accuracy: 0.9043 - val_loss: 0.0443
# Epoch 24/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.7945 - loss: 0.0648 - val_accuracy: 0.7566 - val_loss: 0.0702
# Epoch 25/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - accuracy: 0.8539 - loss: 0.0439 - val_accuracy: 0.9441 - val_loss: 0.0184
# Epoch 26/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.8539 - loss: 0.0451 - val_accuracy: 0.8906 - val_loss: 0.0360
# Epoch 27/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.8336 - loss: 0.0544 - val_accuracy: 0.9266 - val_loss: 0.0235
# Epoch 28/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.8488 - loss: 0.0455 - val_accuracy: 0.8551 - val_loss: 0.0454
# Epoch 29/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - accuracy: 0.8172 - loss: 0.0560 - val_accuracy: 0.8902 - val_loss: 0.0340
# Epoch 30/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.8863 - loss: 0.0357 - val_accuracy: 0.9402 - val_loss: 0.0198
# Epoch 31/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.8938 - loss: 0.0334 - val_accuracy: 0.9102 - val_loss: 0.0288
# Epoch 32/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.8914 - loss: 0.0345 - val_accuracy: 0.6145 - val_loss: 0.0945
# Epoch 33/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - accuracy: 0.8734 - loss: 0.0392 - val_accuracy: 0.9305 - val_loss: 0.0223
# Epoch 34/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.8777 - loss: 0.0386 - val_accuracy: 0.8770 - val_loss: 0.0383
# Epoch 35/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.8887 - loss: 0.0349 - val_accuracy: 0.8199 - val_loss: 0.0566
# Epoch 36/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 0.8992 - loss: 0.0310 - val_accuracy: 0.8910 - val_loss: 0.0339
# Epoch 37/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.9055 - loss: 0.0296 - val_accuracy: 0.8934 - val_loss: 0.0331
# Epoch 38/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - accuracy: 0.9098 - loss: 0.0274 - val_accuracy: 0.8984 - val_loss: 0.0300
# Epoch 39/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9207 - loss: 0.0255 - val_accuracy: 0.7437 - val_loss: 0.0804
# Epoch 40/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.9137 - loss: 0.0269 - val_accuracy: 0.8930 - val_loss: 0.0331
# Epoch 41/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 0.9137 - loss: 0.0276 - val_accuracy: 0.9039 - val_loss: 0.0289
# Epoch 42/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - accuracy: 0.9258 - loss: 0.0235 - val_accuracy: 0.9219 - val_loss: 0.0239
# Epoch 43/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.8898 - loss: 0.0350 - val_accuracy: 0.8742 - val_loss: 0.0385
# Epoch 44/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.8695 - loss: 0.0413 - val_accuracy: 0.8734 - val_loss: 0.0359
# Epoch 45/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.9164 - loss: 0.0271 - val_accuracy: 0.9262 - val_loss: 0.0238
# Epoch 46/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.9242 - loss: 0.0238 - val_accuracy: 0.8973 - val_loss: 0.0317
# Epoch 47/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.9238 - loss: 0.0240 - val_accuracy: 0.9094 - val_loss: 0.0282
# Epoch 48/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.9215 - loss: 0.0255 - val_accuracy: 0.9371 - val_loss: 0.0199
# Epoch 49/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 0.9297 - loss: 0.0220 - val_accuracy: 0.9449 - val_loss: 0.0177
# Epoch 50/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.9238 - loss: 0.0243 - val_accuracy: 0.8348 - val_loss: 0.0513
# Epoch 51/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - accuracy: 0.9227 - loss: 0.0253 - val_accuracy: 0.9395 - val_loss: 0.0203
# Epoch 52/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 0.9254 - loss: 0.0242 - val_accuracy: 0.8543 - val_loss: 0.0443
# Epoch 53/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.9242 - loss: 0.0247 - val_accuracy: 0.9266 - val_loss: 0.0232
# Epoch 54/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 0.9219 - loss: 0.0257 - val_accuracy: 0.8684 - val_loss: 0.0428
# Epoch 55/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.9215 - loss: 0.0257 - val_accuracy: 0.9418 - val_loss: 0.0189
# Epoch 56/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.9328 - loss: 0.0219 - val_accuracy: 0.9355 - val_loss: 0.0199
# Epoch 57/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - accuracy: 0.9203 - loss: 0.0248 - val_accuracy: 0.9109 - val_loss: 0.0282
# Epoch 58/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - accuracy: 0.9340 - loss: 0.0206 - val_accuracy: 0.9223 - val_loss: 0.0253
# Epoch 59/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.9168 - loss: 0.0271 - val_accuracy: 0.8809 - val_loss: 0.0385
# Epoch 60/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9293 - loss: 0.0238 - val_accuracy: 0.9348 - val_loss: 0.0201
# Epoch 61/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 0.9395 - loss: 0.0198 - val_accuracy: 0.9230 - val_loss: 0.0234
# Epoch 62/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - accuracy: 0.9270 - loss: 0.0236 - val_accuracy: 0.9195 - val_loss: 0.0265
# Epoch 63/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - accuracy: 0.9242 - loss: 0.0251 - val_accuracy: 0.9461 - val_loss: 0.0169
# Epoch 64/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - accuracy: 0.9148 - loss: 0.0270 - val_accuracy: 0.9184 - val_loss: 0.0268
# Epoch 65/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 0.9332 - loss: 0.0208 - val_accuracy: 0.9293 - val_loss: 0.0214
# Epoch 66/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - accuracy: 0.9262 - loss: 0.0239 - val_accuracy: 0.9262 - val_loss: 0.0246
# Epoch 67/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - accuracy: 0.9262 - loss: 0.0237 - val_accuracy: 0.9242 - val_loss: 0.0240
# Epoch 68/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.9242 - loss: 0.0235 - val_accuracy: 0.8852 - val_loss: 0.0366
# Epoch 69/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.9332 - loss: 0.0210 - val_accuracy: 0.9285 - val_loss: 0.0225
# Epoch 70/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.9391 - loss: 0.0199 - val_accuracy: 0.9383 - val_loss: 0.0192
# Epoch 71/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.9402 - loss: 0.0203 - val_accuracy: 0.9207 - val_loss: 0.0256
# Epoch 72/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - accuracy: 0.9418 - loss: 0.0195 - val_accuracy: 0.9305 - val_loss: 0.0228
# Epoch 73/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 0.9320 - loss: 0.0228 - val_accuracy: 0.9262 - val_loss: 0.0259
# Epoch 74/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 0.9426 - loss: 0.0191 - val_accuracy: 0.8891 - val_loss: 0.0370
# Epoch 75/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.9320 - loss: 0.0216 - val_accuracy: 0.9363 - val_loss: 0.0200
# Epoch 76/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9297 - loss: 0.0227 - val_accuracy: 0.9398 - val_loss: 0.0185
# Epoch 77/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - accuracy: 0.9426 - loss: 0.0176 - val_accuracy: 0.9422 - val_loss: 0.0185
# Epoch 78/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - accuracy: 0.9461 - loss: 0.0173 - val_accuracy: 0.9359 - val_loss: 0.0199
# Epoch 79/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.9406 - loss: 0.0188 - val_accuracy: 0.9336 - val_loss: 0.0211
# Epoch 80/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 0.9242 - loss: 0.0235 - val_accuracy: 0.9445 - val_loss: 0.0183
# Epoch 81/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.9469 - loss: 0.0179 - val_accuracy: 0.9434 - val_loss: 0.0180
# Epoch 82/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - accuracy: 0.9387 - loss: 0.0201 - val_accuracy: 0.8730 - val_loss: 0.0411
# Epoch 83/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 0.9430 - loss: 0.0187 - val_accuracy: 0.9457 - val_loss: 0.0179
# Epoch 84/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.9504 - loss: 0.0164 - val_accuracy: 0.9270 - val_loss: 0.0227
# Epoch 85/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - accuracy: 0.9348 - loss: 0.0209 - val_accuracy: 0.9430 - val_loss: 0.0176
# Epoch 86/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - accuracy: 0.9359 - loss: 0.0206 - val_accuracy: 0.9375 - val_loss: 0.0198
# Epoch 87/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.9410 - loss: 0.0193 - val_accuracy: 0.9148 - val_loss: 0.0252
# Epoch 88/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9398 - loss: 0.0188 - val_accuracy: 0.9234 - val_loss: 0.0246
# Epoch 89/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - accuracy: 0.9324 - loss: 0.0216 - val_accuracy: 0.9469 - val_loss: 0.0166
# Epoch 90/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - accuracy: 0.9402 - loss: 0.0197 - val_accuracy: 0.9477 - val_loss: 0.0162
# Epoch 91/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - accuracy: 0.9332 - loss: 0.0222 - val_accuracy: 0.9449 - val_loss: 0.0170
# Epoch 92/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - accuracy: 0.9469 - loss: 0.0171 - val_accuracy: 0.9395 - val_loss: 0.0181
# Epoch 93/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.9477 - loss: 0.0167 - val_accuracy: 0.9168 - val_loss: 0.0252
# Epoch 94/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - accuracy: 0.9441 - loss: 0.0179 - val_accuracy: 0.9320 - val_loss: 0.0213
# Epoch 95/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 0.9453 - loss: 0.0181 - val_accuracy: 0.9469 - val_loss: 0.0178
# Epoch 96/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.9469 - loss: 0.0162 - val_accuracy: 0.9445 - val_loss: 0.0162
# Epoch 97/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - accuracy: 0.9449 - loss: 0.0166 - val_accuracy: 0.9473 - val_loss: 0.0153
# Epoch 98/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - accuracy: 0.9445 - loss: 0.0182 - val_accuracy: 0.9402 - val_loss: 0.0189
# Epoch 99/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9473 - loss: 0.0172 - val_accuracy: 0.9398 - val_loss: 0.0197
# Epoch 100/100
# 160/160 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - accuracy: 0.9438 - loss: 0.0186 - val_accuracy: 0.9445 - val_loss: 0.0178
# Model performance:
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - accuracy: 0.9598 - loss: 0.0135
# 	Train loss:     0.0135
# 	Train accuracy: 95.98
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - accuracy: 0.9539 - loss: 0.0152
# 	Test loss:      0.0152
# 	Test accuracy:  95.39
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step
# 512/512 ━━━━━━━━━━━━━━━━━━━━ 0s 257us/step
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# ### Our MLP
# To make sure our implementation of the MLP works as intended, we can run inference using the weights we trained with Keras. Then we can see if we get the same results in terms of accuracy and the decision boundaries generated by the model.
#
# #### Task 2
# Implement the "activation", "setup_model", "feedforward", and "evaluate" functions in "mlp.py". Run this cell and compare the results to the results generated by the Keras model in the previous cell (compare number of weights, classification loss/accuracy, and the plots with decision boundaries). Test this for different specifications of the model in the previous cell (number of hidden layers, layer width, and activation function)
#
# #### Task 3
# Use the linear dataset with 2 classes (K=2). Change the specification of the model parameters. Instead of extracting the weights from the Keras model, you should manually specify a weight matrix (2x2) and a bias vector (2x1), i.e. no hidden layers. Remember that each layer is supposed to be an item in a list, which means that you need to specify the weight matrix and the bias vector in separate 1-item lists. As we only have one layer, it will use the 'softmax' activation function.
# * Manually derive weights and biases to specify a model that draws a decision boundary at x2 = 1-x1. What is the simplest possible solution? How many additional solutions are possible?
# * How can you, in the simplest way, change the weights/biases to switch the predicted class labels?
# * By writing out the output of the MLP, motivate why your choice of weights and biases creates a decision boundary at x2 = 1-x1. Can you find a general formula for specifying which combinations of weights and biases will generate the decision boundary?

# %%
import numpy as np
import mlp
importlib.reload(mlp)

# Get the weight matrices and biases of the trained Keras model
W, b = model_k.get_weights()

# Task 3: specify a weight matrix and a bias vector
#W = TODO
#b = TODO

# This is our implementation of an MLP, which we set to use the dataset we generated
model = mlp.MLP(data)

# Assign the weights and biases to the MLP and specify the activation function
model.setup_model(W, b, activation=activation)

# Evaluate the model (accuracy on the training and test data)
model.evaluate()

# Plot the dataset with decision boundaries generated by our MLP
data.plot_classifier(model)
